# %% [markdown]
# ## Esercitazione 5 MNI

# %% [markdown]
# ### Comandi per l'installazione di CUDA e del compilatore nvcc

# %%
# !wget wget http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run -O cuda_10.2.deb

# %%
# !apt-get update

# %%
# !apt-get install cuda-10.2

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git

# %%
# !nvcc --version

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Navigazione fino alla cartella desiderata

# %%
cd

# %%
cd '/content/drive/MyDrive/MNI/Esercitazione5'

# %%
! ls

# %% [markdown]
# ### Compilazione ed Esecuzione

# %%
! nvcc -Xptxas -v -o somma-matrici-facoltativo somma-matrici-facoltativo.cu

# %%
! ./somma-matrici-facoltativo
# Out:
# Inserire dimensionioni delle matrici: 8192 8192
# blockDim = (16,16)
# gridDim = (512,512)
#
# Tempo di esecuzione parallelo (GPU): 0.018053s
#
# Tempo di esecuzione sequenziale (CPU): 0.470366s

# %%
! nvidia-smi
