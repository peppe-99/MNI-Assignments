# %% [markdown]
# ## Esercitazione 6 MNI

# %% [markdown]
# ### Comandi per l'installazione di CUDA e del compilatore nvcc

# %%
! wget http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run -O cuda_10.2.deb

# %%
# !apt-get update

# %%
# !apt-get install cuda-10.2

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git

# %%
# !nvcc --version
# Out:
# L'esecuzione di celle con 'Python 3.10.6 64-bit' richiede il pacchetto ipykernel.
#
# Eseguire il comando seguente per installare 'ipykernel' nell'ambiente Python.
#
# Comando: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Navigazione fino alla cartella desiderata

# %%
cd

# %%
cd '/content/drive/MyDrive/MNI/Esercitazione6'

# %%
! ls

# %% [markdown]
# ### Compilazione ed Esecuzione

# %%
! nvcc -Xptxas -v -o prodotto-scalare-strategia3 prodotto-scalare-strategia3.cu
# Out:
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function '_Z16prodottoScalare3PfS_S_i' for 'sm_52'
# ptxas info    : Function properties for _Z16prodottoScalare3PfS_S_i
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 9 registers, 348 bytes cmem[0]

# %%
! ./prodotto-scalare-strategia3
# Out:
# Inserire dimensione vettori: 32000000
#
# blockDim = 64
# gridDim = 500000
# Prodotto Scalare: -6119.552246
# Prodotto Sequenziale: -6119.799316
# Tempo di Esecuzione: 0.002950

# %%
! nvidia-smi
