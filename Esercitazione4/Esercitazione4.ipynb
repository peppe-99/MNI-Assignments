# %% [markdown]
# ## Esercitazione 4 MNI

# %% [markdown]
# ### Comandi per l'installazione di CUDA ed il compilatore nvcc

# %%
# !wget wget http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run -O cuda_10.2.deb

# %%
# !apt-get update

# %%
# !apt-get install cuda-10.2

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git

# %%
# !nvcc --version

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Navigazione fino alla cartella desiderata

# %%
! cd
! cd '/content/drive/MyDrive/MNI/Esercitazione4'
! ls

# %% [markdown]
# ### Compilazione ed Esecuzione

# %%
! nvcc -Xptxas -v -o prodotto-scalare prodotto-scalare.cu

# %%
! ./prodotto-scalare
# Out:
# Inserisci numero elementi dei vettori: 32000000
#
# blockDim: 64
# gridDim: 500000
#
#
# Oracolo:-6154.042109
# Prodotto Scalare: -6154.042109
#
# Tempo di esecuzione parallelo (GPU): 0.260836s
#
# Tempo di esecuzione sequenziale (CPU): 0.099446s

# %%
! nvidia-smi
