# %% [markdown]
# ## Esercitazione 7 MNI

# %% [markdown]
# ### Comandi per l'installazione di CUDA e del compilatore nvcc

# %%
! wget http://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda_10.2.89_440.33.01_linux.run -O cuda_10.2.deb

# %%
# !apt-get update

# %%
# !apt-get install cuda-10.2

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git

# %%
# !nvcc --version

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Navigazione fino alla cartella desiderata

# %%
cd

# %%
cd '/content/drive/MyDrive/MNI/Esercitazione7/'

# %%
! ls

# %% [markdown]
# ### Compilazione ed Esecuzione

# %%
! nvcc -o cublas_pmatvet_facoltativo cublas_pmatvet_facoltativo.cu -lcublas

# %%
! ./cublas_pmatvet_facoltativo
# Out:
# Inserisci dimensioni matrice: 16384 16384
# tcmalloc: large alloc 1073741824 bytes == 0x5641ccf8a000 @  0x7fb70996c1e7 0x5641cac0783d 0x7fb701f7bc87 0x5641cac0768a
#
# Tempo di esecuzione cublas: 0.004778s
# Tempo di esecuzione sequenziale: 0.889432s
# Speedup: 186.133453

# %%
! nvidia-smi
